# %% [markdown]
#     Ian Van Dusen's Abswers sheet for Lab 1 for GEOG 590

# %%
import numpy as np
a = 5
b = 3
c = np.multiply(a, b)
print(c)
# Out:
# 15

# %% [markdown]
# ![SouthSister.jpeg](attachment:SouthSister.jpeg)
#
# I am *excited* to ski this winter and spring especially for **Volcano Season**. Here is the [guide](https://www.summitpost.org/south-sister/150455) to ski South Sister.
